# %%
from duckduckgo_search import *
from fastcore.all import *
from fastbook import *

# %%
path = Path('images')
image_types = 'plastic litter on the city street: litter only', 'cigarette butts'
def download_images_ddg(img_category, img_types, num_images):
    if not path.exists():
        path.mkdir()
        for o in img_types:
            dest = (path/o)
            dest.mkdir(exist_ok=True)
            results = search_images_ddg(f'{str(o)} {img_category}', max_images=num_images)
            if 'next' in results:
                for u in range(len(results['next'])):
                    try:
                        download_url(results['next'][u], ...)
                    except Exception as e:
                        print(f'Error downloading image: {e}')
            else:
                print('No more results available.')
            
            for u in range(len(results)):
                try:
                    download_url(url=results[u], 
                                 dest=f'{dest}/{str(o)}-{str(u+1)}.jpg', 
                                 timeout=400, 
                                 show_progress=False)
                except:
                    print(f'not found {results[u]}')
                    continue

# %%
download_images_ddg('litter', image_types, 300)
# Out:
# ['http://st2.dripimg.com/1370000/13966/12/1368783_1920_b6db7e.jpg', 'https://c8.alamy.com/comp/BC7ECP/refuse-collectors-picking-up-litter-left-on-the-street-when-seagulls-BC7ECP.jpg', 'https://s3-prod.sustainableplastics.com/s3fs-public/styles/800x600/public/PRW_160109962_AR_-1_IYKYRDMSMKBD.jpg', 'http://i1.dripimg.com/t/1370000/13966/12/1368786_800_6c8d01.jpg', 'http://i4.walesonline.co.uk/incoming/article11679244.ece/ALTERNATES/s615/JS95690757JPG.jpg', 'https://c8.alamy.com/comp/FFKNAC/typical-litter-found-on-the-streets-mcdonalds-fast-food-and-drink-FFKNAC.jpg', 'https://whyy.org/wp-content/uploads/planphilly/assets_13/img-2737.original.jpg', 'https://www.bathecho.co.uk/uploads/2016/06/wasteonstreet_benhowlett.jpg', 'https://c8.alamy.com/comp/BD2FWM/dont-litter-sign-on-sidewalk-warning-public-prohibition-nara-kansai-BD2FWM.jpg', 'https://litteritcostsyou.org/wp-content/uploads/2018/12/Men-are-likely-to-litter-more-than-women-do-300x264.jpg', 'https://www.undp.org/sites/g/files/zsk
# ...

# %%
fns = get_image_files(path)
failed = verify_images(fns)
failed.map(Path.unlink);

# %%
folders = []
#iterate through folder to store different images as datablocks
for item in os.listdir(path):
        item_path = os.path.join(path, item)
        if os.path.isdir(item_path):
            print('processing',item_path)
            litter_type_datablock = DataBlock(
                                    blocks=(ImageBlock, CategoryBlock), 
                                    get_items=get_image_files, 
                                    splitter=RandomSplitter(valid_pct=0.2, seed=42),
                                    get_y=parent_label,
                                    item_tfms=Resize(128))
            dls = litter_type_datablock.dataloaders(item_path)
            dls.valid.show_batch(max_n=4, nrows=1)

# %%
# training the model

# %%
for k,v in dataloaders.items():
    print(k,v,path)
    item_path = os.path.join(path, k)
    v = v.new(
        item_tfms=RandomResizedCrop(224, min_scale=0.5),
        batch_tfms=aug_transforms())
    print('item path', item_path)
    dls = v.dataloaders(item_path)
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[80], line 6
#       4 item_path = path/img_type
#       5 if item_path.exists():
# ----> 6     dataloaders[img_type] = litter_type_datablock.dataloaders(item_path)
#       7     print(f"Created DataLoader for {img_type}")
#       8     dataloaders[img_type].show_batch(max_n=4, nrows=1)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/block.py:157, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     155 dsets = self.datasets(source, verbose=verbose)
#     156 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 157 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# ...
